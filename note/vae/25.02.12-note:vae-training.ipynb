# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# source_l256 = "/Users/yoshikawa/loutrebleu/menta/stroker/result/2025.02.12.013826/data.csv"
# source_l256 = "/Users/yoshikawa/loutrebleu/menta/stroker/result/2025.02.12.015001/data.csv"
source_L4 = "/Users/yoshikawa/loutrebleu/menta/stroker/result/2025.02.12.020933/data.csv"
source_L5 = "/Users/yoshikawa/loutrebleu/menta/stroker/result/2025.02.12.021840/data.csv"
source_L3 = "/Users/yoshikawa/loutrebleu/menta/stroker/result/2025.02.12.022908/data.csv"

# %%
data = [
    pd.read_csv(source_L3),
    pd.read_csv(source_L4),
    pd.read_csv(source_L5),
]
label = ["L=3", "L=4", "L=5"]

# %%
fig, axes = plt.subplots(nrows=3, sharex=True, figsize=(10, 6))
for l, d in zip(label, data):
    d.plot(x="step", y="loss", ax=axes[0], label=l)
    d.plot(x="step", y="kl_loss", ax=axes[1], label=l)
    d.plot(x="step", y="rc_loss", ax=axes[2], label=l)
plt.xlim(0, 1500)
# axes[0].set_yscale("log")
# axes[2].set_yscale("log")
plt.legend()
plt.show()
plt.("/Users/yoshikawa/loutrebleu/menta/stroker/result/lossesL345.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       9 plt.legend()
#      10 plt.show()
# ---> 11 plt.imsave("/Users/yoshikawa/loutrebleu/menta/stroker/result/lossesL345.png")
#
# TypeError: imsave() missing 1 required positional argument: 'arr'
